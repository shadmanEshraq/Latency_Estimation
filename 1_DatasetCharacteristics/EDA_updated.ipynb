# %% [markdown]
# # Extended EDA

# %%
# Initialization Cell
# %reset -f
print("Environment cleared. Starting fresh.")


import pyarrow.parquet as pq
import pandas as pd
import numpy as np
# Out:
# Environment cleared. Starting fresh.

# %% [markdown]
# ## Plot Configuration

# %%
# Matplotlib configuration for consistent styling across all plots

import matplotlib.pyplot as plt

plt.rcParams.update(
    {
        # Figure
        # "figure.figsize": (10, 6),
        "figure.dpi": 150,
        # Fonts
        "font.size": 12,
        "axes.titlesize": 16,
        "axes.titleweight": "bold",
        "axes.labelsize": 13,
        "axes.labelweight": "bold",
        # Tick labels
        "xtick.labelsize": 11,
        "ytick.labelsize": 11,
        # Legend
        "legend.fontsize": 10,
        "legend.shadow": True,
        # Grid
        "axes.grid": True,
        "grid.alpha": 0.25,
        # Lines
        "lines.linewidth": 2,
        # Save quality
        "savefig.bbox": "tight",
    }
)



# Seaborn configuration for enhanced aesthetics
import seaborn as sns
sns.set_theme(style="whitegrid", context="talk", font_scale=1)

# %%
# file path
ping_file_name = 'df_1.0pt_sample.parquet'

# load the parquet file and cast into pandas dataframe
df= pd.read_parquet(ping_file_name)

df.head()
# Out:
#                   timestamp         src_addr        dst_addr  sent  rcvd  dup  \
# 1085898 2026-05-18 00:22:04  104.225.102.122  103.225.148.38     3     3    0
# 873663  2026-05-18 00:17:59    153.92.43.250   89.185.60.124     3     3    0
# 497001  2026-05-18 00:17:34  206.162.189.131   79.135.106.48     3     3    0
# 74125   2026-05-18 00:48:39   195.191.197.68    193.3.165.56     3     3    0
# 1101900 2026-05-18 00:07:19    34.168.44.215   77.46.127.110     3     3    0
#
#                 min         max         avg  src_continent  ... dst_is_proxy  \
# 1085898  194.861124  195.354425  195.049542  North America  ...        False
# 873663    13.138776   13.209956   13.181569         Europe  ...        False
# 497001   110.322972  110.390421  110.359401  North America  ...        False
# 74125     18.957661   18.974771   18.966589         Europe  ...        False
# 1101900  154.178701  154.267123  154.213704  North America  ...        False
#
#          dst_is_vpn  dst_is_tor  dst_is_tor_exit hop_count   distance_km  \
# 1085898       False       False            False      14.0  14995.178447
# 873663        False       False            False      10.0    320.588698
# 497001         True       False            False     255.0   5483.327488
# 74125         False       False            False      11.0    633.366009
# 1101900       False       False            False       6.0   8525.473243
#
#         src_prefix_8 src_prefix_16 dst_prefix_8 dst_prefix_16
# 1085898          104       104.225          103       103.225
# 873663           153        153.92           89        89.185
# 497001           206       206.162           79        79.135
# 74125            195       195.191          193         193.3
# 1101900           34        34.168           77         77.46
#
# [5 rows x 41 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 11168 entries, 1085898 to 819077
# Data columns (total 41 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   timestamp              11168 non-null  datetime64[us]
#  1   src_addr               11168 non-null  str
#  2   dst_addr               11168 non-null  str
#  3   sent                   11168 non-null  int64
#  4   rcvd                   11168 non-null  int64
#  5   dup                    11168 non-null  int64
#  6   min                    11168 non-null  float64
#  7   max                    11168 non-null  float64
#  8   avg                    11168 non-null  float64
#  9   src_continent          10956 non-null  str
#  10  src_country            11154 non-null  str
#  11  src_longitude          11162 non-null  float64
#  12  src_latitude           11162 non-null  float64
#  13  src_asn                11162 non-null  float64
#  14  src_conn_type          11162 non-null  str
#  15  src_provider           11162 non-null  str
#  16  src_is_mobile          11162 non-null  object
#  17  src_is_cloud_provider  11162 non-null  object
#  18  src_is_proxy           11162 non-null  object
#  19  src_is_vpn             11162 non-null  object
#  20  src_is_tor             11162 non-null  object
#  21  src_is_tor_exit        11162 non-null  object
#  22  dst_continent          10955 non-null  str
#  23  dst_country            11157 non-null  str
#  24  dst_longitude          11168 non-null  float64
#  25  dst_latitude           11168 non-null  float64
#  26  dst_asn                11168 non-null  float64
#  27  dst_conn_type          11168 non-null  str
#  28  dst_provider           11153 non-null  str
#  29  dst_is_mobile          11168 non-null  bool
#  30  dst_is_cloud_provider  11168 non-null  bool
#  31  dst_is_proxy           11168 non-null  bool
#  32  dst_is_vpn             11168 non-null  bool
#  33  dst_is_tor             11168 non-null  bool
#  34  dst_is_tor_exit        11168 non-null  bool
#  35  hop_count              11136 non-null  float64
#  36  distance_km            11162 non-null  float64
#  37  src_prefix_8           11168 non-null  str
#  38  src_prefix_16          11168 non-null  str
#  39  dst_prefix_8           11168 non-null  str
#  40  dst_prefix_16          11168 non-null  str
# dtypes: bool(6), datetime64[us](1), float64(11), int64(3), object(6), str(14)
# memory usage: 4.3+ MB

# %%
from eda_pipeline import EDAPipeline
eda = EDAPipeline(df = df, target='avg')
eda.run_all()
# Out:
# ============================================================
# DATASET OVERVIEW
# ============================================================
# Shape: (11168, 41)
#
# Columns:
# ['timestamp', 'src_addr', 'dst_addr', 'sent', 'rcvd', 'dup', 'min', 'max', 'avg', 'src_continent', 'src_country', 'src_longitude', 'src_latitude', 'src_asn', 'src_conn_type', 'src_provider', 'src_is_mobile', 'src_is_cloud_provider', 'src_is_proxy', 'src_is_vpn', 'src_is_tor', 'src_is_tor_exit', 'dst_continent', 'dst_country', 'dst_longitude', 'dst_latitude', 'dst_asn', 'dst_conn_type', 'dst_provider', 'dst_is_mobile', 'dst_is_cloud_provider', 'dst_is_proxy', 'dst_is_vpn', 'dst_is_tor', 'dst_is_tor_exit', 'hop_count', 'distance_km', 'src_prefix_8', 'src_prefix_16', 'dst_prefix_8', 'dst_prefix_16']
#
# Data Types:
# timestamp                datetime64[us]
# src_addr                            str
# dst_addr                            str
# sent                              int64
# rcvd                              int64
# dup                               int64
# min                             float64
# max                             float64
# avg                             float64
# src_continent                       str
# src_country                         str
# src_longitude                   float64
# src_latitude                    float64
# src_asn                         float64
# src_conn_type                       str
# src_provider                        str
# src_is_mobile                    object
# src_is_cloud_provider            object
# src_is_proxy                     object
# src_is_vpn                       object
# src_is_tor                       object
# src_is_tor_exit                  object
# dst_continent                       str
# dst_country                         str
# dst_longitude                   float64
# dst_latitude                    float64
# dst_asn                         float64
# dst_conn_type                       str
# dst_provider                        str
# dst_is_mobile                      bool
# dst_is_cloud_provider              bool
# dst_is_proxy                       bool
# dst_is_vpn                         bool
# dst_is_tor                         bool
# dst_is_tor_exit                    bool
# hop_count                       float64
# distance_km                     float64
# src_prefix_8                        str
# src_prefix_16                       str
# dst_prefix_8                        str
# dst_prefix_16                       str
# dtype: object
#
# Missing Values:
# dst_continent            213
# src_continent            212
# hop_count                 32
# dst_provider              15
# src_country               14
# dst_country               11
# src_asn                    6
# src_conn_type              6
# src_is_mobile              6
# distance_km                6
# src_is_tor_exit            6
# src_is_cloud_provider      6
# src_is_proxy               6
# src_is_tor                 6
# src_is_vpn                 6
# src_longitude              6
# src_latitude               6
# src_provider               6
# timestamp                  0
# min                        0
# dup                        0
# rcvd                       0
# sent                       0
# dst_addr                   0
# src_addr                   0
# avg                        0
# max                        0
# dst_longitude              0
# dst_latitude               0
# dst_is_mobile              0
# dst_is_cloud_provider      0
# dst_asn                    0
# dst_conn_type              0
# dst_is_vpn                 0
# dst_is_proxy               0
# dst_is_tor_exit            0
# dst_is_tor                 0
# src_prefix_8               0
# src_prefix_16              0
# dst_prefix_8               0
# dst_prefix_16              0
# dtype: int64
#
# Duplicate Rows:
# 0
# ============================================================
# MEMORY USAGE
# ============================================================
# Dataset memory usage: 6.11 MB
#
#
# ============================================================
# NUMERICAL SUMMARY
# ============================================================
#                  count          mean            std         min           25%  \
# sent           11168.0      3.000269       0.230440    1.000000      3.000000
# rcvd           11168.0      2.994628       0.251026    1.000000      3.000000
# dup            11168.0      0.008238       0.151776    0.000000      0.000000
# min            11168.0    129.411138      91.834851    0.061039     40.779015
# max            11168.0    130.877629      92.618084    0.188862     41.746317
# avg            11168.0    130.037614      91.989101    0.149060     41.375409
# src_longitude  11162.0      5.762821      66.304892 -157.858270     -3.702580
# src_latitude   11162.0     35.392750      24.787219  -50.340850     33.748750
# src_asn        11162.0  81704.134116   97662.018394    4.000000  16276.000000
# dst_longitude  11168.0      6.357021      67.297044 -123.136740     -8.470660
# dst_latitude   11168.0     34.596581      25.017115  -50.340850     32.018540
# dst_asn        11168.0  86797.444842  100117.416560   16.000000  17893.000000
# hop_count      11136.0     25.435165      53.543103    1.000000     10.000000
# distance_km    11162.0   6413.229526    4749.348114    0.000000   1546.570657
#
#                         50%            75%            max
# sent               3.000000       3.000000      10.000000
# rcvd               3.000000       3.000000      10.000000
# dup                0.000000       0.000000       3.000000
# min              124.679332     192.133116     758.168968
# max              125.875451     193.730953     758.168968
# avg              125.312729     192.903105     758.168968
# src_longitude      8.682120      26.049555     179.194180
# src_latitude      45.545470      50.850520      69.648920
# src_asn        39617.000000  139759.000000  401665.000000
# dst_longitude      8.684080      27.728420     179.194180
# dst_latitude      44.871710      50.115470      67.282740
# dst_asn        42207.000000  150000.000000  401612.000000
# hop_count         13.000000      16.000000     255.000000
# distance_km     6673.315905    9559.209430   19773.500287
#
#
# ============================================================
# MISSING VALUE REPORT
# ============================================================
#                        missing_count  missing_percent
# dst_continent                    213         1.907235
# src_continent                    212         1.898281
# hop_count                         32         0.286533
# dst_provider                      15         0.134312
# src_country                       14         0.125358
# dst_country                       11         0.098496
# src_asn                            6         0.053725
# src_conn_type                      6         0.053725
# src_is_mobile                      6         0.053725
# distance_km                        6         0.053725
# src_is_tor_exit                    6         0.053725
# src_is_cloud_provider              6         0.053725
# src_is_proxy                       6         0.053725
# src_is_tor                         6         0.053725
# src_is_vpn                         6         0.053725
# src_longitude                      6         0.053725
# src_latitude                       6         0.053725
# src_provider                       6         0.053725
# timestamp                          0         0.000000
# min                                0         0.000000
# dup                                0         0.000000
# rcvd                               0         0.000000
# sent                               0         0.000000
# dst_addr                           0         0.000000
# src_addr                           0         0.000000
# avg                                0         0.000000
# max                                0         0.000000
# dst_longitude                      0         0.000000
# dst_latitude                       0         0.000000
# dst_is_mobile                      0         0.000000
# dst_is_cloud_provider              0         0.000000
# dst_asn                            0         0.000000
# dst_conn_type                      0         0.000000
# dst_is_vpn                         0         0.000000
# dst_is_proxy                       0         0.000000
# dst_is_tor_exit                    0         0.000000
# dst_is_tor                         0         0.000000
# src_prefix_8                       0         0.000000
# src_prefix_16                      0         0.000000
# dst_prefix_8                       0         0.000000
# dst_prefix_16                      0         0.000000
#
#
# ============================================================
# CARDINALITY REPORT
# ============================================================
#                        unique_values  cardinality_percent
# src_addr                      2285.0            20.460244
# src_prefix_16                 1761.0            15.768266
# src_provider                  1275.0            11.416547
# dst_addr                      1033.0             9.249642
# dst_prefix_16                  793.0             7.100645
# dst_provider                   717.0             6.420129
# src_prefix_8                   189.0             1.692335
# dst_prefix_8                   138.0             1.235673
# src_country                    116.0             1.038682
# dst_country                    104.0             0.931232
# dst_continent                    6.0             0.053725
# src_continent                    6.0             0.053725
# src_conn_type                    5.0             0.044771
# dst_conn_type                    5.0             0.044771
# src_is_vpn                       2.0             0.017908
# src_is_proxy                     2.0             0.017908
# src_is_cloud_provider            2.0             0.017908
# src_is_mobile                    2.0             0.017908
# dst_is_vpn                       2.0             0.017908
# dst_is_cloud_provider            2.0             0.017908
# src_is_tor                       2.0             0.017908
# dst_is_mobile                    2.0             0.017908
# src_is_tor_exit                  1.0             0.008954
# dst_is_tor_exit                  1.0             0.008954
# dst_is_proxy                     1.0             0.008954
# dst_is_tor                       1.0             0.008954
#
#
# ============================================================
# OUTLIER REPORT
# ============================================================
#                outlier_count
# sent                      77
# rcvd                     116
# dup                       34
# min                       13
# max                       20
# avg                       14
# src_longitude           4274
# src_latitude            1640
# src_asn                  459
# dst_longitude           3972
# dst_latitude            1600
# dst_asn                  386
# hop_count                652
# distance_km                0
#
#
# ============================================================
# SKEWNESS REPORT
# ============================================================
#                 skewness
# sent           24.344282
# dup            18.791241
# rcvd           17.727918
# hop_count       4.025781
# src_asn         1.551538
# dst_asn         1.475287
# max             0.536944
# avg             0.509161
# min             0.507978
# distance_km     0.375370
# dst_longitude   0.116387
# src_longitude   0.113395
# dst_latitude   -1.598761
# src_latitude   -1.681583
#
#
# ============================================================
# LOG TRANSFORM CANDIDATES
# ============================================================
#      feature  skewness
# 0       sent    24.344
# 2        dup    18.791
# 1       rcvd    17.728
# 5  hop_count     4.026
# 3    src_asn     1.552
# 4    dst_asn     1.475
#
#
# ============================================================
# Showing correlation heatmap...
# ============================================================
# ============================================================
# Showing distribution plots...
# ============================================================
# ============================================================
# Showing boxplots...
# ============================================================
# ============================================================
# Showing target vs feature relationships...
# ============================================================
# ============================================================
# Task complete! All EDA steps have been executed.
# ============================================================
