# %% [markdown]
# # Extended EDA

# %%
# Initialization Cell
# %reset -f
print("Environment cleared. Starting fresh.")

# !pip install pyarrow
import pyarrow.parquet as pq
import pandas as pd
import numpy as np
# Out:
# Environment cleared. Starting fresh.

# %%
# file path
file_path = '/workspaces/Latency_Estimation/1_DatasetCharacteristics/dataset/df_original.parquet'


# load the parquet file and cast into pandas dataframe
df= pd.read_parquet(file_path)

# %%
from eda_pipeline import EDAPipeline
eda = EDAPipeline(df = df, target='avg')
eda.run_all()
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#                      🚀 EDA Script Started !
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ============================================================
# DATASET OVERVIEW
# ============================================================
# Shape: (1116767, 41)
# Number of rows: 1116767
# Number of columns: 41
#
# Columns:
# ------------------------------
# ['timestamp',
#  'src_addr',
#  'dst_addr',
#  'sent',
#  'rcvd',
#  'dup',
#  'min',
#  'max',
#  'avg',
#  'src_continent',
#  'src_country',
#  'src_longitude',
#  'src_latitude',
#  'src_asn',
#  'src_conn_type',
#  'src_provider',
#  'src_is_mobile',
#  'src_is_cloud_provider',
#  'src_is_proxy',
#  'src_is_vpn',
#  'src_is_tor',
#  'src_is_tor_exit',
#  'dst_continent',
#  'dst_country',
#  'dst_longitude',
#  'dst_latitude',
#  'dst_asn',
#  'dst_conn_type',
#  'dst_provider',
#  'dst_is_mobile',
#  'dst_is_cloud_provider',
#  'dst_is_proxy',
#  'dst_is_vpn',
#  'dst_is_tor',
#  'dst_is_tor_exit',
#  'hop_count',
#  'distance_km',
#  'src_prefix_8',
#  'src_prefix_16',
#  'dst_prefix_8',
#  'dst_prefix_16']
#
# Data Types:
# #------------------------------ 🚨 Check for Typecast Issues ! 🚨------------------------------#
#
# timestamp                datetime64[us]
# src_addr                            str
# dst_addr                            str
# sent                              int64
# rcvd                              int64
# dup                               int64
# min                             float64
# max                             float64
# avg                             float64
# src_continent                       str
# src_country                         str
# src_longitude                   float64
# src_latitude                    float64
# src_asn                         float64
# src_conn_type                       str
# src_provider                        str
# src_is_mobile                    object
# src_is_cloud_provider            object
# src_is_proxy                     object
# src_is_vpn                       object
# src_is_tor                       object
# src_is_tor_exit                  object
# dst_continent                       str
# dst_country                         str
# dst_longitude                   float64
# dst_latitude                    float64
# dst_asn                         float64
# dst_conn_type                       str
# dst_provider                        str
# dst_is_mobile                      bool
# dst_is_cloud_provider              bool
# dst_is_proxy                       bool
# dst_is_vpn                         bool
# dst_is_tor                         bool
# dst_is_tor_exit                    bool
# hop_count                       float64
# distance_km                     float64
# src_prefix_8                        str
# src_prefix_16                       str
# dst_prefix_8                        str
# dst_prefix_16                       str
# dtype: object
#
# 🚨 Missing Values:
# ------------------------------
# src_continent            19717
# dst_continent            19516
# hop_count                 3648
# src_country               1389
# dst_country               1083
# dst_provider               814
# src_provider               308
# src_asn                    249
# src_conn_type              249
# distance_km                248
# src_is_tor_exit            248
# src_is_mobile              248
# src_is_proxy               248
# src_is_tor                 248
# src_is_vpn                 248
# src_is_cloud_provider      248
# src_longitude              248
# src_latitude               248
# dst_conn_type                1
# dst_asn                      1
# timestamp                    0
# rcvd                         0
# sent                         0
# dst_addr                     0
# src_addr                     0
# avg                          0
# max                          0
# min                          0
# dup                          0
# dst_longitude                0
# dst_is_cloud_provider        0
# dst_is_mobile                0
# dst_latitude                 0
# dst_is_vpn                   0
# dst_is_proxy                 0
# dst_is_tor_exit              0
# dst_is_tor                   0
# src_prefix_8                 0
# src_prefix_16                0
# dst_prefix_8                 0
# dst_prefix_16                0
# dtype: int64
#
# 🚨 Duplicate Rows:
# ------------------------------
# np.int64(0)
# ============================================================
# MEMORY USAGE
# ============================================================
# Dataset memory usage: 602.33 MB
#
#
# ============================================================
#  🔢 NUMERICAL SUMMARY 🔢
# ============================================================
#                    count          mean           std         min  \
# sent           1116767.0      2.997678      0.200805    1.000000
# rcvd           1116767.0      2.992609      0.220735    1.000000
# dup            1116767.0      0.011686      0.749413    0.000000
# min            1116767.0    130.025320     93.002782    0.000000
# max            1116767.0    131.660731     94.340616    0.020340
# avg            1116767.0    130.717387     93.279785    0.019206
# src_longitude  1116519.0      6.662239     66.089890 -159.775490
# src_latitude   1116519.0     35.344331     24.945577  -54.510880
# src_asn        1116518.0  81562.228900  97416.743912    4.000000
# dst_longitude  1116767.0      6.538874     67.128906 -123.136740
# dst_latitude   1116767.0     34.734141     25.071883  -50.340850
# dst_asn        1116766.0  86218.332113  99379.162617   16.000000
# hop_count      1113119.0     24.871460     52.471442    1.000000
# distance_km    1116519.0   6403.187813   4753.873808    0.000000
#
#                         25%           50%            75%            max
# sent               3.000000      3.000000       3.000000      10.000000
# rcvd               3.000000      3.000000       3.000000      10.000000
# dup                0.000000      0.000000       0.000000     165.000000
# min               40.205867    124.552365     193.586500     991.788404
# max               41.309596    126.041251     195.375056    2315.298861
# avg               40.762408    125.244953     194.399122    1066.399570
# src_longitude     -3.657250      8.684080      26.102530     179.194180
# src_latitude      33.622700     45.749140      50.850520      69.968790
# src_asn        16276.000000  39642.000000  139225.000000  402164.000000
# dst_longitude     -4.483280      8.684080      28.043690     179.194180
# dst_latitude      32.725380     45.070510      50.279690      67.282740
# dst_asn        17893.000000  42207.000000  149697.000000  401612.000000
# hop_count         10.000000     13.000000      16.000000     255.000000
# distance_km     1513.945408   6698.980975    9571.421040   19981.655209
#
#
# ================================================================================
# 🚨 MISSING VALUE REPORT 🚨
# ================================================================================
#                        missing_count  missing_percent (%)
# src_continent                  19717             1.765543
# dst_continent                  19516             1.747544
# hop_count                       3648             0.326657
# src_country                     1389             0.124377
# dst_country                     1083             0.096976
# dst_provider                     814             0.072889
# src_provider                     308             0.027580
# src_asn                          249             0.022297
# src_conn_type                    249             0.022297
# distance_km                      248             0.022207
# src_is_tor_exit                  248             0.022207
# src_is_mobile                    248             0.022207
# src_is_proxy                     248             0.022207
# src_is_tor                       248             0.022207
# src_is_vpn                       248             0.022207
# src_is_cloud_provider            248             0.022207
# src_longitude                    248             0.022207
# src_latitude                     248             0.022207
# dst_conn_type                      1             0.000090
# dst_asn                            1             0.000090
# timestamp                          0             0.000000
# rcvd                               0             0.000000
# sent                               0             0.000000
# dst_addr                           0             0.000000
# src_addr                           0             0.000000
# avg                                0             0.000000
# max                                0             0.000000
# min                                0             0.000000
# dup                                0             0.000000
# dst_longitude                      0             0.000000
# dst_is_cloud_provider              0             0.000000
# dst_is_mobile                      0             0.000000
# dst_latitude                       0             0.000000
# dst_is_vpn                         0             0.000000
# dst_is_proxy                       0             0.000000
# dst_is_tor_exit                    0             0.000000
# dst_is_tor                         0             0.000000
# src_prefix_8                       0             0.000000
# src_prefix_16                      0             0.000000
# dst_prefix_8                       0             0.000000
# dst_prefix_16                      0             0.000000
#
#
# ================================================================================
# 🔠 CARDINALITY REPORT 🔠
# ================================================================================
#                       unique_values cardinality_percent (%)  \
# src_addr                      10726                0.960451
# src_prefix_16                  6129                0.548816
# src_provider                   3266                0.292451
# dst_addr                       1377                0.123302
# dst_prefix_16                  1044                0.093484
# dst_provider                    789                 0.07065
# src_prefix_8                    202                0.018088
# dst_prefix_8                    169                0.015133
# src_country                     155                0.013879
# dst_country                     108                0.009671
# dst_continent                     6                0.000537
# src_continent                     6                0.000537
# src_conn_type                     6                0.000537
# dst_conn_type                     5                0.000448
# src_is_tor                        2                0.000179
# src_is_tor_exit                   2                0.000179
# src_is_vpn                        2                0.000179
# src_is_mobile                     2                0.000179
# dst_is_mobile                     2                0.000179
# dst_is_cloud_provider             2                0.000179
# dst_is_proxy                      2                0.000179
# dst_is_vpn                        2                0.000179
# src_is_proxy                      2                0.000179
# src_is_cloud_provider             2                0.000179
# dst_is_tor                        1                 0.00009
# dst_is_tor_exit                   1                 0.00009
#
#                                               suggestion
# src_addr                 consider typecast to 'category'
# src_prefix_16            consider typecast to 'category'
# src_provider             consider typecast to 'category'
# dst_addr                 consider typecast to 'category'
# dst_prefix_16            consider typecast to 'category'
# dst_provider             consider typecast to 'category'
# src_prefix_8             consider typecast to 'category'
# dst_prefix_8             consider typecast to 'category'
# src_country              consider typecast to 'category'
# dst_country              consider typecast to 'category'
# dst_continent            consider typecast to 'category'
# src_continent            consider typecast to 'category'
# src_conn_type            consider typecast to 'category'
# dst_conn_type            consider typecast to 'category'
# src_is_tor             bool flag/ consider bool typecast
# src_is_tor_exit        bool flag/ consider bool typecast
# src_is_vpn             bool flag/ consider bool typecast
# src_is_mobile          bool flag/ consider bool typecast
# dst_is_mobile          bool flag/ consider bool typecast
# dst_is_cloud_provider  bool flag/ consider bool typecast
# dst_is_proxy           bool flag/ consider bool typecast
# dst_is_vpn             bool flag/ consider bool typecast
# src_is_proxy           bool flag/ consider bool typecast
# src_is_cloud_provider  bool flag/ consider bool typecast
# dst_is_tor             bool flag/ consider bool typecast
# dst_is_tor_exit        bool flag/ consider bool typecast
#
#
# ================================================================================
# 💡 OUTLIER REPORT 💡
# ================================================================================
#                outlier_count
# src_longitude         425047
# dst_longitude         419681
# src_latitude          167174
# dst_latitude          165241
# hop_count              63184
# src_asn                45515
# dst_asn                36878
# rcvd                   10791
# sent                    7448
# dup                     3298
# max                     2646
# avg                     2158
# min                     2025
# distance_km                0
#
#
# ================================================================================
# 💡 SKEWNESS REPORT 💡
# ================================================================================
#                  skewness
# dup            179.849659
# sent            24.278911
# rcvd            16.389967
# hop_count        4.127747
# src_asn          1.551061
# dst_asn          1.477340
# max              0.665382
# avg              0.530529
# min              0.520252
# distance_km      0.370640
# src_longitude    0.123947
# dst_longitude    0.112346
# dst_latitude    -1.604083
# src_latitude    -1.657409
#
#
# ================================================================================
# 💡 LOG TRANSFORM CANDIDATES 💡
# ================================================================================
#      feature  skewness
# 2        dup   179.850
# 0       sent    24.279
# 1       rcvd    16.390
# 5  hop_count     4.128
# 3    src_asn     1.551
# 4    dst_asn     1.477
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#                      Printing plots...
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
# ================================================================================
#                     🌡️ Showing correlation heatmap...
# ================================================================================
# ================================================================================
#                     📊 Showing distribution plots...
# ================================================================================
# --------------------------------------------------------------------------------
#                     📊 Showing boxplots...
# --------------------------------------------------------------------------------
# ================================================================================
#                     📈 Showing target vs feature relationships...
# ================================================================================
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#                     ✅ Task complete! All EDA steps have been executed.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
