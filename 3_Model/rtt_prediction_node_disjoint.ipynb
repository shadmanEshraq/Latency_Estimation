# %% [markdown]
# # RTT Prediction Using Network Metadata
#
# This notebook predicts average RTT between network peers using geographic, routing, and metadata-based features.
# A node-disjoint train/test split is used so that test peers are never observed during training.

# %%
import hashlib
from pathlib import Path

import numpy as np
import pandas as pd
import polars as pl
import matplotlib.pyplot as plt

from sklearn.feature_selection import mutual_info_regression
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# ## Node-Disjoint Train/Test Split
#
# Instead of randomly splitting rows, nodes are assigned to either the training or test partition.
# Only pairs where both endpoints belong to the same partition are kept. This prevents the same IP address from appearing in both training and testing data.

# %%
N_LANDMARKS = 150
TEST_FRACTION = 0.30
SPLIT_SALT = "lat-est-v1"


def bucket(addr):
    digest = hashlib.blake2b(
        f"{SPLIT_SALT}:{addr}".encode(),
        digest_size=8
    ).digest()
    return int.from_bytes(digest, "big") % 10000


def assign_roles(df):
    dual = set(df["src_addr"]) & set(df["dst_addr"])

    ranked = (
        pl.concat([
            df.select(pl.col("src_addr").alias("addr")),
            df.select(pl.col("dst_addr").alias("addr"))
        ])
        .filter(pl.col("addr").is_in(dual))
        .group_by("addr")
        .len()
        .with_columns(
            tie=pl.col("addr").map_elements(
                bucket,
                return_dtype=pl.Int64
            )
        )
        .sort(["len", "tie"], descending=[True, False])
    )

    landmarks = set(ranked.head(N_LANDMARKS)["addr"])
    peers = dual - landmarks

    test_peers = {
        p for p in peers
        if bucket(p) < TEST_FRACTION * 10000
    }

    train_peers = peers - test_peers

    return landmarks, train_peers, test_peers

# %% [markdown]
# ## Dataset Loading
#
# The dataset is loaded from a local parquet file.
# For reproducibility, update `DATA_PATH` to point to the location of `df_original.parquet`.

# %%
DATA_PATH = Path("data/df_original.parquet)
if not DATA_PATH.exists():
    raise FileNotFoundError(
        "Dataset not found. Place df_original.parquet inside the data/ folder "
        "or update DATA_PATH to your local path."
    )

pdf = pd.read_parquet(DATA_PATH)
df_polars = pl.from_pandas(pdf)

landmarks, train_peers, test_peers = assign_roles(df_polars)

train_df = pdf[
    pdf["src_addr"].isin(train_peers) &
    pdf["dst_addr"].isin(train_peers)
].copy()

test_df = pdf[
    pdf["src_addr"].isin(test_peers) &
    pdf["dst_addr"].isin(test_peers)
].copy()

print("Full dataset:", pdf.shape)
print("Train set:", train_df.shape)
print("Test set:", test_df.shape)
print("Train peers:", len(train_peers))
print("Test peers:", len(test_peers))
print("Landmarks:", len(landmarks))
print("Test row fraction:", test_df.shape[0] / (train_df.shape[0] + test_df.shape[0]))
# Out:
# Full dataset: (1116767, 41)
# Train set: (322372, 41)
# Test set: (62078, 41)
# Train peers: 586
# Test peers: 258
# Landmarks: 150
# Test row fraction: 0.16147223306021588

# %% [markdown]
# ## Exploratory Data Analysis
#
# This section summarizes the full RTT dataset and visualizes the distribution of the target variable and key network-related features.

# %%
df = pdf.copy()

print("Dataset shape:")
print(df.shape)

print("\nColumns:")
print(df.columns.tolist())

print("\nMissing values:")
print(df.isna().sum().sort_values(ascending=False).head(15))

numeric_cols = df.select_dtypes(
    include=["int64", "float64"]
).columns

print("\nNumerical summary:")
display(df[numeric_cols].describe())

plt.figure(figsize=(10, 6))
plt.hist(df["avg"].dropna(), bins=100)
plt.title("RTT Average Distribution")
plt.xlabel("Average RTT (ms)")
plt.ylabel("Count")
plt.show()

plt.figure(figsize=(10, 6))
plt.hist(df["hop_count"].dropna(), bins=40)
plt.title("Hop Count Distribution")
plt.xlabel("Hop Count")
plt.ylabel("Count")
plt.show()

plt.figure(figsize=(10, 6))
plt.hist(df["distance_km"].dropna(), bins=100)
plt.title("Geographic Distance Distribution")
plt.xlabel("Distance (km)")
plt.ylabel("Count")
plt.show()

plt.figure(figsize=(10, 6))
df["dst_continent"].value_counts().plot(kind="bar")
plt.title("Destination Continents")
plt.xlabel("Continent")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

print("\nUnique destination ASNs:")
print(df["dst_asn"].nunique())

print("\nTop destination ASNs:")
print(df["dst_asn"].value_counts().head(20))

print("\nTop destination providers:")
print(df["dst_provider"].value_counts().head(20))

security_cols = [
    "dst_is_vpn",
    "dst_is_proxy",
    "dst_is_tor",
    "dst_is_cloud_provider"
]

for col in security_cols:
    print(f"\n{col}:")
    print(df[col].value_counts())

corr_cols = [
    "avg",
    "min",
    "max",
    "hop_count",
    "distance_km",
    "sent",
    "rcvd",
    "dup"
]

corr_df = df[corr_cols].corr()

print("\nCorrelation matrix:")
display(corr_df)

plt.figure(figsize=(8, 6))
plt.imshow(corr_df)
plt.xticks(range(len(corr_cols)), corr_cols, rotation=45)
plt.yticks(range(len(corr_cols)), corr_cols)
plt.colorbar()
plt.title("Correlation Matrix")
plt.show()
# Out:
# Dataset shape:
# (1116767, 41)
#
# Columns:
# ['timestamp', 'src_addr', 'dst_addr', 'sent', 'rcvd', 'dup', 'min', 'max', 'avg', 'src_continent', 'src_country', 'src_longitude', 'src_latitude', 'src_asn', 'src_conn_type', 'src_provider', 'src_is_mobile', 'src_is_cloud_provider', 'src_is_proxy', 'src_is_vpn', 'src_is_tor', 'src_is_tor_exit', 'dst_continent', 'dst_country', 'dst_longitude', 'dst_latitude', 'dst_asn', 'dst_conn_type', 'dst_provider', 'dst_is_mobile', 'dst_is_cloud_provider', 'dst_is_proxy', 'dst_is_vpn', 'dst_is_tor', 'dst_is_tor_exit', 'hop_count', 'distance_km', 'src_prefix_8', 'src_prefix_16', 'dst_prefix_8', 'dst_prefix_16']
#
# Missing values:
# src_continent      19717
# dst_continent      19516
# hop_count           3648
# src_country         1389
# dst_country         1083
# dst_provider         814
# src_provider         308
# src_asn              249
# src_conn_type        249
# distance_km          248
# src_is_tor_exit      248
# src_is_mobile        248
# src_is_proxy         248
# src_is_tor           248
# src_is_vpn           248
# dtype: int64
#
# Numerical summary:
#                sent          rcvd           dup           min           max  \
# count  1.116767e+06  1.116767e+06  1.116767e+06  1.116767e+06  1.116767e+06
# mean   2.997678e+00  2.992609e+00  1.168641e-02  1.300253e+02  1.316607e+02
# std    2.008050e-01  2.207345e-01  7.494133e-01  9.300278e+01  9.434062e+01
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  2.034000e-02
# 25%    3.000000e+00  3.000000e+00  0.000000e+00  4.020587e+01  4.130960e+01
# 50%    3.000000e+00  3.000000e+00  0.000000e+00  1.245524e+02  1.260413e+02
# 75%    3.000000e+00  3.000000e+00  0.000000e+00  1.935865e+02  1.953751e+02
# max    1.000000e+01  1.000000e+01  1.650000e+02  9.917884e+02  2.315299e+03
#
#                 avg  src_longitude  src_latitude       src_asn  dst_longitude  \
# count  1.116767e+06   1.116519e+06  1.116519e+06  1.116518e+06   1.116767e+06
# mean   1.307174e+02   6.662239e+00  3.534433e+01  8.156223e+04   6.538874e+00
# std    9.327979e+01   6.608989e+01  2.494558e+01  9.741674e+04   6.712891e+01
# min    1.920633e-02  -1.597755e+02 -5.451088e+01  4.000000e+00  -1.231367e+02
# 25%    4.076241e+01  -3.657250e+00  3.362270e+01  1.627600e+04  -4.483280e+00
# 50%    1.252450e+02   8.684080e+00  4.574914e+01  3.964200e+04   8.684080e+00
# 75%    1.943991e+02   2.610253e+01  5.085052e+01  1.392250e+05   2.804369e+01
# max    1.066400e+03   1.791942e+02  6.996879e+01  4.021640e+05   1.791942e+02
#
#        dst_latitude       dst_asn     hop_count   distance_km
# count  1.116767e+06  1.116766e+06  1.113119e+06  1.116519e+06
# mean   3.473414e+01  8.621833e+04  2.487146e+01  6.403188e+03
# std    2.507188e+01  9.937916e+04  5.247144e+01  4.753874e+03
# min   -5.034085e+01  1.600000e+01  1.000000e+00  0.000000e+00
# 25%    3.272538e+01  1.789300e+04  1.000000e+01  1.513945e+03
# 50%    4.507051e+01  4.220700e+04  1.300000e+01  6.698981e+03
# 75%    5.027969e+01  1.496970e+05  1.600000e+01  9.571421e+03
# max    6.728274e+01  4.016120e+05  2.550000e+02  1.998166e+04
# Unique destination ASNs:
# 847
#
# Top destination ASNs:
# dst_asn
# 16552.0     28899
# 20473.0     19332
# 202422.0    16305
# 31713.0     13386
# 48503.0     13039
# 14061.0      8965
# 36236.0      8618
# 208398.0     8082
# 16276.0      7660
# 199610.0     6564
# 55002.0      6321
# 680.0        6249
# 197556.0     5619
# 21299.0      5605
# 14907.0      5554
# 37468.0      5413
# 58057.0      5297
# 42473.0      5240
# 3320.0       4949
# 4826.0       4764
# Name: count, dtype: int64
#
# Top destination providers:
# dst_provider
# digicert.com        28899
# constant.com        19332
# gcore.lu            17436
# pccwglobal.com      15607
# tele2.kz            13039
# beeline.kz          11224
# misaka.email        10183
# digitalocean.com     8965
# netactuate.com       8618
# twnic.net            8615
# tele.tech            8082
# ovh.net              7660
# criteo.com           6855
# apjii.or.id          6728
# nitrado.net          6564
# anexia.at            6448
# securebit.ch         6321
# f5.com               6321
# dfn.de               6249
# wikimedia.org        5554
# Name: count, dtype: int64
#
# dst_is_vpn:
# dst_is_vpn
# False    1101263
# True       15504
# Name: count, dtype: int64
#
# dst_is_proxy:
# dst_is_proxy
# False    1116765
# True           2
# Name: count, dtype: int64
#
# dst_is_tor:
# dst_is_tor
# False    1116767
# Name: count, dtype: int64
#
# dst_is_cloud_provider:
# dst_is_cloud_provider
# True     648763
# False    468004
# Name: count, dtype: int64
#
# Correlation matrix:
#                   avg       min       max  hop_count  distance_km      sent  \
# avg          1.000000  0.998103  0.995398   0.098654     0.873243 -0.017014
# min          0.998103  1.000000  0.988005   0.098774     0.875847 -0.016802
# max          0.995398  0.988005  1.000000   0.097640     0.863329 -0.016101
# hop_count    0.098654  0.098774  0.097640   1.000000     0.096366 -0.005075
# distance_km  0.873243  0.875847  0.863329   0.096366     1.000000 -0.020343
# sent        -0.017014 -0.016802 -0.016101  -0.005075    -0.020343  1.000000
# rcvd        -0.023244 -0.022917 -0.022423  -0.008586    -0.019305  0.921387
# dup          0.003123  0.002995  0.003227  -0.000659     0.000354 -0.000183
#
#                  rcvd       dup
# avg         -0.023244  0.003123
# min         -0.022917  0.002995
# max         -0.022423  0.003227
# hop_count   -0.008586 -0.000659
# distance_km -0.019305  0.000354
# sent         0.921387 -0.000183
# rcvd         1.000000 -0.000192
# dup         -0.000192  1.000000

# %% [markdown]
# ## Mutual Information Feature Analysis
#
# Mutual Information is computed on the training set only, in order to estimate the predictive relevance of each feature without using information from the test set.

# %%
df_fi = train_df.copy()

target = "avg"

features = [
    "distance_km",
    "hop_count",
    "src_asn",
    "dst_asn",
    "src_continent",
    "dst_continent",
    "src_country",
    "dst_country",
    "src_provider",
    "dst_provider",
    "sent",
    "rcvd",
    "dup",
    "src_conn_type",
    "dst_conn_type",
    "dst_is_vpn",
    "dst_is_cloud_provider",
    "dst_is_proxy",
    "dst_is_tor",
    "src_prefix_8",
    "src_prefix_16",
    "dst_prefix_8",
    "dst_prefix_16"
]

features = [f for f in features if f in df_fi.columns]

df_fi = df_fi[features + [target]].copy()
df_fi = df_fi[df_fi[target].notna()]

for col in features:
    if df_fi[col].dtype == "object":
        df_fi[col] = df_fi[col].fillna("unknown")
        le = LabelEncoder()
        df_fi[col] = le.fit_transform(df_fi[col].astype(str))
    else:
        df_fi[col] = df_fi[col].fillna(df_fi[col].median())

X_mi = df_fi[features]
y_mi = df_fi[target]

mi_scores = mutual_info_regression(
    X_mi,
    y_mi,
    random_state=42
)

mi_df = pd.DataFrame({
    "Feature": features,
    "MI Score": mi_scores
}).sort_values(by="MI Score", ascending=False)

display(mi_df)

plt.figure(figsize=(12, 6))
plt.bar(mi_df["Feature"], mi_df["MI Score"])
plt.title("Mutual Information Feature Importance")
plt.xlabel("Feature")
plt.ylabel("Mutual Information Score")
plt.xticks(rotation=45, ha="right")
plt.show()
# Out:
#                   Feature      MI Score
# 0             distance_km  1.618592e+00
# 20          src_prefix_16  4.505032e-01
# 22          dst_prefix_16  4.471992e-01
# 8            src_provider  4.122571e-01
# 9            dst_provider  4.108050e-01
# 7             dst_country  3.690014e-01
# 6             src_country  3.660354e-01
# 2                 src_asn  3.144129e-01
# 3                 dst_asn  3.136777e-01
# 19           src_prefix_8  2.286311e-01
# 5           dst_continent  2.269856e-01
# 21           dst_prefix_8  2.259938e-01
# 4           src_continent  2.248561e-01
# 1               hop_count  1.310495e-01
# 13          src_conn_type  1.623993e-02
# 14          dst_conn_type  1.458549e-02
# 16  dst_is_cloud_provider  8.292032e-03
# 12                    dup  1.922096e-03
# 11                   rcvd  1.898131e-03
# 15             dst_is_vpn  1.031049e-03
# 10                   sent  1.010872e-03
# 18             dst_is_tor  1.110223e-15
# 17           dst_is_proxy  1.110223e-15

# %% [markdown]
# ## Random Forest Baseline Model
#
# A Random Forest Regressor is trained using the node-disjoint training set and evaluated on unseen test peers.
# Categorical features are label-encoded and missing values are imputed using statistics from the training set.

# %%
target = "avg"

features = [
    "distance_km",
    "hop_count",
    "src_asn",
    "dst_asn",
    "src_continent",
    "dst_continent",
    "src_country",
    "dst_country",
    "src_provider",
    "dst_provider",
    "src_prefix_16",
    "dst_prefix_16",
    "src_conn_type",
    "dst_conn_type"
]

features = [f for f in features if f in train_df.columns]

train_model = train_df[features + [target]].copy()
test_model = test_df[features + [target]].copy()

train_model = train_model[train_model[target].notna()]
test_model = test_model[test_model[target].notna()]

for col in features:
    if train_model[col].dtype == "object":
        train_model[col] = train_model[col].fillna("unknown")
        test_model[col] = test_model[col].fillna("unknown")

        le = LabelEncoder()
        le.fit(train_model[col].astype(str))

        train_model[col] = le.transform(train_model[col].astype(str))

        test_model[col] = test_model[col].astype(str)
        test_model[col] = test_model[col].where(
            test_model[col].isin(le.classes_),
            "unknown"
        )

        if "unknown" not in le.classes_:
            le.classes_ = np.append(le.classes_, "unknown")

        test_model[col] = le.transform(test_model[col])

    else:
        median_value = train_model[col].median()
        train_model[col] = train_model[col].fillna(median_value)
        test_model[col] = test_model[col].fillna(median_value)

bool_cols = train_model.select_dtypes(include=["bool"]).columns

for col in bool_cols:
    train_model[col] = train_model[col].astype(int)
    test_model[col] = test_model[col].astype(int)

X_train = train_model[features]
y_train = train_model[target]

X_test = test_model[features]
y_test = test_model[target]

print("Train size:", X_train.shape)
print("Test size:", X_test.shape)

model = RandomForestRegressor(
    n_estimators=100,
    max_depth=20,
    min_samples_leaf=5,
    random_state=42,
    n_jobs=-1
)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print("\nMODEL PERFORMANCE")
print("-----------------")
print(f"MAE  : {mae:.3f} ms")
print(f"RMSE : {rmse:.3f} ms")
print(f"R²   : {r2:.4f}")

importance_df = pd.DataFrame({
    "Feature": features,
    "Importance": model.feature_importances_
}).sort_values(by="Importance", ascending=False)

print("\nRandom Forest Feature Importance:")
display(importance_df)

plt.figure(figsize=(12, 6))
plt.bar(importance_df["Feature"], importance_df["Importance"])
plt.title("Random Forest Feature Importance")
plt.xlabel("Feature")
plt.ylabel("Importance")
plt.xticks(rotation=45, ha="right")
plt.show()

comparison_df = pd.DataFrame({
    "Actual RTT": y_test.values,
    "Predicted RTT": y_pred,
    "Absolute Error": np.abs(y_test.values - y_pred)
})

display(comparison_df.head(20))

plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.2, s=10)
plt.xlabel("Actual RTT (ms)")
plt.ylabel("Predicted RTT (ms)")
plt.title("Actual vs Predicted RTT")
plt.show()
# Out:
# Train size: (322372, 14)
# Test size: (62078, 14)
#
# MODEL PERFORMANCE
# -----------------
# MAE  : 24.942 ms
# RMSE : 39.820 ms
# R²   : 0.8269
#
# Random Forest Feature Importance:
#           Feature  Importance
# 0     distance_km    0.829708
# 4   src_continent    0.038362
# 5   dst_continent    0.037668
# 6     src_country    0.015924
# 7     dst_country    0.015880
# 1       hop_count    0.011721
# 10  src_prefix_16    0.009669
# 11  dst_prefix_16    0.009115
# 9    dst_provider    0.006714
# 3         dst_asn    0.006520
# 2         src_asn    0.006328
# 8    src_provider    0.006243
# 13  dst_conn_type    0.003222
# 12  src_conn_type    0.002926
#     Actual RTT  Predicted RTT  Absolute Error
# 0    39.512068      41.627123        2.115054
# 1   246.011939     265.231720       19.219781
# 2    14.535816      20.468801        5.932984
# 3    92.743060     156.901150       64.158090
# 4   105.479054     108.353019        2.873965
# 5    84.348080     142.832100       58.484020
# 6    24.709315      18.563112        6.146204
# 7   156.140367     154.964673        1.175693
# 8    80.505519      88.231072        7.725553
# 9    61.720975      74.692701       12.971726
# 10  220.470486     278.063875       57.593389
# 11  291.908182     268.220258       23.687925
# 12  106.585123     105.618801        0.966322
# 13  265.395040     283.207940       17.812900
# 14  319.680836     267.845065       51.835771
# 15  121.667227     144.224742       22.557514
# 16  327.391987     303.556609       23.835378
# 17  263.520526     265.945651        2.425125
# 18   99.590937     168.509409       68.918471
# 19  168.185760     174.184731        5.998971

# %% [markdown]
# ## Random Forest Hyperparameter Tuning
#
# Several Random Forest configurations are evaluated by varying the number of trees, tree depth, and leaf size. The objective is to determine whether a more complex ensemble can improve prediction accuracy on unseen peers.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import pandas as pd
import numpy as np

rf_results = []

configs = [
    (100, 20, 5),
    (200, 20, 5),
    (300, 20, 5),

    (100, 25, 5),
    (200, 25, 5),
    (300, 25, 5),

    (100, None, 5),
    (200, None, 5),

    (100, 20, 2),
    (200, 20, 2),

    (100, 30, 1),
    (200, 30, 1),
]

for n_estimators, max_depth, min_samples_leaf in configs:

    print(
        f"Running RF: trees={n_estimators}, "
        f"depth={max_depth}, "
        f"leaf={min_samples_leaf}"
    )

    model = RandomForestRegressor(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_leaf=min_samples_leaf,
        random_state=42,
        n_jobs=-1
    )

    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    rf_results.append({
        "n_estimators": n_estimators,
        "max_depth": max_depth,
        "min_samples_leaf": min_samples_leaf,
        "R2": r2_score(y_test, y_pred),
        "MAE": mean_absolute_error(y_test, y_pred),
        "RMSE": np.sqrt(mean_squared_error(y_test, y_pred))
    })

rf_results_df = pd.DataFrame(rf_results)
rf_results_df = rf_results_df.sort_values(
    by="R2",
    ascending=False
)

display(rf_results_df)

print("\nBest Random Forest configuration:")
display(rf_results_df.head(1))
# Out:
# Running RF: trees=100, depth=20, leaf=5
# Running RF: trees=200, depth=20, leaf=5
# Running RF: trees=300, depth=20, leaf=5
# Running RF: trees=100, depth=25, leaf=5
# Running RF: trees=200, depth=25, leaf=5
# Running RF: trees=300, depth=25, leaf=5
# Running RF: trees=100, depth=None, leaf=5
# Running RF: trees=200, depth=None, leaf=5
# Running RF: trees=100, depth=20, leaf=2
# Running RF: trees=200, depth=20, leaf=2
# Running RF: trees=100, depth=30, leaf=1
# Running RF: trees=200, depth=30, leaf=1
#     n_estimators  max_depth  min_samples_leaf        R2        MAE       RMSE
# 5            300       25.0                 5  0.829154  24.975415  39.556093
# 2            300       20.0                 5  0.829125  24.827289  39.559490
# 4            200       25.0                 5  0.828728  24.989836  39.605474
# 1            200       20.0                 5  0.828659  24.842725  39.613406
# 7            200        NaN                 5  0.828453  25.031099  39.637212
# 3            100       25.0                 5  0.827221  25.051568  39.779310
# 6            100        NaN                 5  0.827002  25.101727  39.804433
# 0            100       20.0                 5  0.826871  24.942402  39.819545
# 9            200       20.0                 2  0.822823  25.720517  40.282427
# 8            100       20.0                 2  0.820508  25.856791  40.544715
# 11           200       30.0                 1  0.812599  27.323627  41.428309
# 10           100       30.0                 1  0.809569  27.481079  41.761910
# Best Random Forest configuration:
#    n_estimators  max_depth  min_samples_leaf        R2        MAE       RMSE
# 5           300       25.0                 5  0.829154  24.975415  39.556093

# %% [markdown]
# ## XGBoost Model Evaluation
#
# XGBoost is evaluated as a gradient boosting alternative to Random Forest. Multiple configurations are tested by varying tree depth, learning rate, and the number of boosting rounds.

# %%
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import pandas as pd
import numpy as np

xgb_results = []

configs = [
    (300, 6, 0.05),
    (500, 6, 0.05),

    (300, 8, 0.05),
    (500, 8, 0.05),

    (300, 10, 0.05),

    (300, 6, 0.10),
    (500, 6, 0.10),

    (300, 8, 0.10),
    (500, 8, 0.10),
]

for n_estimators, max_depth, learning_rate in configs:

    print(
        f"Running XGB: trees={n_estimators}, "
        f"depth={max_depth}, "
        f"lr={learning_rate}"
    )

    model = XGBRegressor(
        n_estimators=n_estimators,
        max_depth=max_depth,
        learning_rate=learning_rate,
        subsample=0.8,
        colsample_bytree=0.8,
        objective="reg:squarederror",
        random_state=42,
        n_jobs=-1
    )

    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    xgb_results.append({
        "n_estimators": n_estimators,
        "max_depth": max_depth,
        "learning_rate": learning_rate,
        "R2": r2_score(y_test, y_pred),
        "MAE": mean_absolute_error(y_test, y_pred),
        "RMSE": np.sqrt(mean_squared_error(y_test, y_pred))
    })

xgb_results_df = pd.DataFrame(xgb_results)
xgb_results_df = xgb_results_df.sort_values(
    by="R2",
    ascending=False
)

display(xgb_results_df)

print("\nBest XGBoost configuration:")
display(xgb_results_df.head(1))
# Out:
# Running XGB: trees=300, depth=6, lr=0.05
# Running XGB: trees=500, depth=6, lr=0.05
# Running XGB: trees=300, depth=8, lr=0.05
# Running XGB: trees=500, depth=8, lr=0.05
# Running XGB: trees=300, depth=10, lr=0.05
# Running XGB: trees=300, depth=6, lr=0.1
# Running XGB: trees=500, depth=6, lr=0.1
# Running XGB: trees=300, depth=8, lr=0.1
# Running XGB: trees=500, depth=8, lr=0.1
#    n_estimators  max_depth  learning_rate        R2        MAE       RMSE
# 2           300          8           0.05  0.846776  25.020077  37.460610
# 4           300         10           0.05  0.845698  25.157619  37.592151
# 3           500          8           0.05  0.842614  25.482783  37.965960
# 8           500          8           0.10  0.841272  24.839288  38.127434
# 7           300          8           0.10  0.841194  24.877617  38.136902
# 0           300          6           0.05  0.839822  25.779747  38.301252
# 1           500          6           0.05  0.839124  25.851313  38.384644
# 5           300          6           0.10  0.836588  25.808363  38.685999
# 6           500          6           0.10  0.836497  25.403642  38.696719
# Best XGBoost configuration:
#    n_estimators  max_depth  learning_rate        R2        MAE      RMSE
# 2           300          8           0.05  0.846776  25.020077  37.46061

# %% [markdown]
# ## LightGBM Model Evaluation
#
# LightGBM is evaluated as a scalable gradient boosting framework designed for large tabular datasets. Different combinations of boosting rounds, leaves, and learning rates are tested.

# %%
from lightgbm import LGBMRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import pandas as pd
import numpy as np

lgbm_results = []

configs = [
    (300, 31, 0.05),
    (500, 31, 0.05),
    (800, 31, 0.05),

    (300, 63, 0.05),
    (500, 63, 0.05),

    (300, 127, 0.05),
    (500, 127, 0.05),

    (300, 31, 0.10),
    (500, 31, 0.10),

    (300, 63, 0.10),
    (500, 63, 0.10),
]

for n_estimators, num_leaves, learning_rate in configs:

    print(
        f"Running LGBM: trees={n_estimators}, "
        f"leaves={num_leaves}, "
        f"lr={learning_rate}"
    )

    model = LGBMRegressor(
        n_estimators=n_estimators,
        num_leaves=num_leaves,
        learning_rate=learning_rate,
        max_depth=-1,
        subsample=0.8,
        colsample_bytree=0.8,
        random_state=42,
        n_jobs=-1,
        verbose=-1
    )

    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    lgbm_results.append({
        "n_estimators": n_estimators,
        "num_leaves": num_leaves,
        "learning_rate": learning_rate,
        "R2": r2_score(y_test, y_pred),
        "MAE": mean_absolute_error(y_test, y_pred),
        "RMSE": np.sqrt(mean_squared_error(y_test, y_pred))
    })

lgbm_results_df = pd.DataFrame(lgbm_results)
lgbm_results_df = lgbm_results_df.sort_values(
    by="R2",
    ascending=False
)

display(lgbm_results_df)

print("\nBest LightGBM configuration:")
display(lgbm_results_df.head(1))
# Out:
# Running LGBM: trees=300, leaves=31, lr=0.05
# Running LGBM: trees=500, leaves=31, lr=0.05
# Running LGBM: trees=800, leaves=31, lr=0.05
# Running LGBM: trees=300, leaves=63, lr=0.05
# Running LGBM: trees=500, leaves=63, lr=0.05
# Running LGBM: trees=300, leaves=127, lr=0.05
# Running LGBM: trees=500, leaves=127, lr=0.05
# Running LGBM: trees=300, leaves=31, lr=0.1
# Running LGBM: trees=500, leaves=31, lr=0.1
# Running LGBM: trees=300, leaves=63, lr=0.1
# Running LGBM: trees=500, leaves=63, lr=0.1
#     n_estimators  num_leaves  learning_rate        R2        MAE       RMSE
# 6            500         127           0.05  0.850872  24.627622  36.956518
# 5            300         127           0.05  0.850705  24.705404  36.977245
# 8            500          31           0.10  0.849008  24.404327  37.186750
# 4            500          63           0.05  0.848286  24.931463  37.275531
# 2            800          31           0.05  0.848002  25.342458  37.310401
# 3            300          63           0.05  0.847690  24.942148  37.348695
# 7            300          31           0.10  0.847373  24.910697  37.387598
# 0            300          31           0.05  0.847303  25.289129  37.396178
# 9            300          63           0.10  0.846362  24.970127  37.511194
# 1            500          31           0.05  0.846221  25.540085  37.528396
# 10           500          63           0.10  0.844948  25.164463  37.683368
# Best LightGBM configuration:
#    n_estimators  num_leaves  learning_rate        R2        MAE       RMSE
# 6           500         127           0.05  0.850872  24.627622  36.956518

# %% [markdown]
# ## PyTorch MLP Neural Network
#
# To investigate whether a neural-network approach can capture latency patterns more effectively than tree-based methods, several Multi-Layer Perceptron (MLP) architectures were evaluated.
#
# The models were trained on standardized features using the Adam optimizer and early stopping. Multiple hidden-layer configurations were tested to assess the effect of network depth and model capacity on prediction performance.
#
# Although neural networks are highly flexible, tabular networking datasets often favor gradient-boosted decision trees, making this comparison particularly interesting.

# %%
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader, random_split

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

import numpy as np
import pandas as pd

# -----------------------------
# Reproducibility
# -----------------------------
torch.manual_seed(42)
np.random.seed(42)

device = torch.device("cpu")
print("Using device:", device)

# -----------------------------
# Scale features
# -----------------------------
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

X_train_tensor = torch.tensor(X_train_scaled, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.float32).view(-1, 1)

X_test_tensor = torch.tensor(X_test_scaled, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.float32).view(-1, 1)

# -----------------------------
# Train / validation split
# -----------------------------
full_train_dataset = TensorDataset(X_train_tensor, y_train_tensor)

val_size = int(0.1 * len(full_train_dataset))
train_size = len(full_train_dataset) - val_size

train_dataset, val_dataset = random_split(
    full_train_dataset,
    [train_size, val_size],
    generator=torch.Generator().manual_seed(42)
)

train_loader = DataLoader(
    train_dataset,
    batch_size=2048,
    shuffle=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=4096,
    shuffle=False
)

test_loader = DataLoader(
    TensorDataset(X_test_tensor, y_test_tensor),
    batch_size=4096,
    shuffle=False
)

# -----------------------------
# Flexible MLP model
# -----------------------------
class MLPRegressorTorch(nn.Module):
    def __init__(self, input_dim, hidden_layers, dropout):
        super().__init__()

        layers = []
        previous_dim = input_dim

        for hidden_dim in hidden_layers:
            layers.append(nn.Linear(previous_dim, hidden_dim))
            layers.append(nn.ReLU())
            layers.append(nn.Dropout(dropout))
            previous_dim = hidden_dim

        layers.append(nn.Linear(previous_dim, 1))

        self.network = nn.Sequential(*layers)

    def forward(self, x):
        return self.network(x)


# -----------------------------
# Architectures to compare
# -----------------------------
configs = [
    {
        "name": "MLP_64_32",
        "hidden_layers": [64, 32],
        "dropout": 0.10,
        "lr": 0.001,
        "weight_decay": 1e-4
    },
    {
        "name": "MLP_128_64",
        "hidden_layers": [128, 64],
        "dropout": 0.10,
        "lr": 0.001,
        "weight_decay": 1e-4
    },
    {
        "name": "MLP_256_128",
        "hidden_layers": [256, 128],
        "dropout": 0.15,
        "lr": 0.001,
        "weight_decay": 1e-4
    },
    {
        "name": "MLP_256_128_64",
        "hidden_layers": [256, 128, 64],
        "dropout": 0.15,
        "lr": 0.001,
        "weight_decay": 1e-4
    }
]

# -----------------------------
# Train and evaluate function
# -----------------------------
def train_and_evaluate_mlp(config):

    model = MLPRegressorTorch(
        input_dim=X_train.shape[1],
        hidden_layers=config["hidden_layers"],
        dropout=config["dropout"]
    ).to(device)

    criterion = nn.MSELoss()

    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=config["lr"],
        weight_decay=config["weight_decay"]
    )

    best_val_loss = np.inf
    best_state = None
    patience = 5
    patience_counter = 0
    max_epochs = 50

    for epoch in range(1, max_epochs + 1):

        model.train()
        train_losses = []

        for xb, yb in train_loader:
            xb = xb.to(device)
            yb = yb.to(device)

            optimizer.zero_grad()

            preds = model(xb)
            loss = criterion(preds, yb)

            loss.backward()
            optimizer.step()

            train_losses.append(loss.item())

        model.eval()
        val_losses = []

        with torch.no_grad():
            for xb, yb in val_loader:
                xb = xb.to(device)
                yb = yb.to(device)

                preds = model(xb)
                loss = criterion(preds, yb)

                val_losses.append(loss.item())

        train_loss = np.mean(train_losses)
        val_loss = np.mean(val_losses)

        print(
            f"{config['name']} | "
            f"Epoch {epoch:03d} | "
            f"Train MSE: {train_loss:.3f} | "
            f"Val MSE: {val_loss:.3f}"
        )

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_state = model.state_dict()
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"{config['name']} | Early stopping triggered.")
            break

    model.load_state_dict(best_state)

    model.eval()

    all_preds = []
    all_targets = []

    with torch.no_grad():
        for xb, yb in test_loader:
            xb = xb.to(device)

            preds = model(xb).cpu().numpy().ravel()

            all_preds.extend(preds)
            all_targets.extend(yb.numpy().ravel())

    y_pred = np.array(all_preds)
    y_true = np.array(all_targets)

    r2 = r2_score(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))

    return {
        "Model": "PyTorch MLP",
        "Architecture": config["name"],
        "Hidden Layers": str(config["hidden_layers"]),
        "Dropout": config["dropout"],
        "LR": config["lr"],
        "Weight Decay": config["weight_decay"],
        "Best Val MSE": best_val_loss,
        "R2": r2,
        "MAE": mae,
        "RMSE": rmse
    }


# -----------------------------
# Run all MLP configurations
# -----------------------------
torch_mlp_results = []

for config in configs:
    print("\n==============================")
    print("Training:", config["name"])
    print("==============================")

    result = train_and_evaluate_mlp(config)
    torch_mlp_results.append(result)

# -----------------------------
# Results table
# -----------------------------
torch_mlp_results_df = pd.DataFrame(torch_mlp_results)

torch_mlp_results_df = torch_mlp_results_df.sort_values(
    by="RMSE",
    ascending=True
).reset_index(drop=True)

display(torch_mlp_results_df)
# Out:
# Using device: cpu
#
# ==============================
# Training: MLP_64_32
# ==============================
# MLP_64_32 | Epoch 001 | Train MSE: 21764.073 | Val MSE: 13270.017
# MLP_64_32 | Epoch 002 | Train MSE: 5644.725 | Val MSE: 2757.263
# MLP_64_32 | Epoch 003 | Train MSE: 2482.498 | Val MSE: 1958.415
# MLP_64_32 | Epoch 004 | Train MSE: 2000.767 | Val MSE: 1712.798
# MLP_64_32 | Epoch 005 | Train MSE: 1858.628 | Val MSE: 1637.057
# MLP_64_32 | Epoch 006 | Train MSE: 1804.355 | Val MSE: 1596.011
# MLP_64_32 | Epoch 007 | Train MSE: 1766.468 | Val MSE: 1559.101
# MLP_64_32 | Epoch 008 | Train MSE: 1733.252 | Val MSE: 1526.413
# MLP_64_32 | Epoch 009 | Train MSE: 1706.243 | Val MSE: 1496.421
# MLP_64_32 | Epoch 010 | Train MSE: 1685.741 | Val MSE: 1470.102
# MLP_64_32 | Epoch 011 | Train MSE: 1663.205 | Val MSE: 1449.383
# MLP_64_32 | Epoch 012 | Train MSE: 1648.870 | Val MSE: 1430.426
# MLP_64_32 | Epoch 013 | Train MSE: 1627.471 | Val MSE: 1410.724
# MLP_64_32 | Epoch 014 | Train MSE: 1616.325 | Val MSE: 1389.748
# MLP_64_32 | Epoch 015 | Train MSE: 1593.382 | Val MSE: 1369.268
# MLP_64_32 | Epoch 016 | Train MSE: 1570.450 | Val MSE: 1348.228
# MLP_64_32 | Epoch 017 | Train MSE: 1557.360 | Val MSE: 1327.417
# MLP_64_32 | Epoch 018 | Train MSE: 1535.975 | Val MSE: 1312.673
# MLP_64_32 | Epoch 019 | Train MSE: 1530.176 | Val MSE: 1298.661
# MLP_64_32 | Epoch 020 | Train MSE: 1517.518 | Val MSE: 1284.902
# MLP_64_32 | Epoch 021 | Train MSE: 1509.279 | Val MSE: 1275.977
# MLP_64_32 | Epoch 022 | Train MSE: 1491.115 | Val MSE: 1265.238
# MLP_64_32 | Epoch 023 | Train MSE: 1485.050 | Val MSE: 1257.418
# MLP_64_32 | Epoch 024 | Train MSE: 1483.754 | Val MSE: 1248.074
# MLP_64_32 | Epoch 025 | Train MSE: 1471.414 | Val MSE: 1238.307
# MLP_64_32 | Epoch 026 | Train MSE: 1468.383 | Val MSE: 1227.747
# MLP_64_32 | Epoch 027 | Train MSE: 1459.717 | Val MSE: 1219.187
# MLP_64_32 | Epoch 028 | Train MSE: 1451.393 | Val MSE: 1210.040
# MLP_64_32 | Epoch 029 | Train MSE: 1449.028 | Val MSE: 1203.109
# MLP_64_32 | Epoch 030 | Train MSE: 1445.431 | Val MSE: 1197.581
# MLP_64_32 | Epoch 031 | Train MSE: 1434.425 | Val MSE: 1191.196
# MLP_64_32 | Epoch 032 | Train MSE: 1425.971 | Val MSE: 1184.508
# MLP_64_32 | Epoch 033 | Train MSE: 1423.458 | Val MSE: 1179.896
# MLP_64_32 | Epoch 034 | Train MSE: 1421.116 | Val MSE: 1173.926
# MLP_64_32 | Epoch 035 | Train MSE: 1410.924 | Val MSE: 1168.159
# MLP_64_32 | Epoch 036 | Train MSE: 1408.067 | Val MSE: 1163.399
# MLP_64_32 | Epoch 037 | Train MSE: 1410.029 | Val MSE: 1160.107
# MLP_64_32 | Epoch 038 | Train MSE: 1405.979 | Val MSE: 1155.446
# MLP_64_32 | Epoch 039 | Train MSE: 1398.678 | Val MSE: 1151.557
# MLP_64_32 | Epoch 040 | Train MSE: 1400.762 | Val MSE: 1147.258
# MLP_64_32 | Epoch 041 | Train MSE: 1396.941 | Val MSE: 1142.712
# MLP_64_32 | Epoch 042 | Train MSE: 1391.550 | Val MSE: 1141.387
# MLP_64_32 | Epoch 043 | Train MSE: 1387.346 | Val MSE: 1137.766
# MLP_64_32 | Epoch 044 | Train MSE: 1391.205 | Val MSE: 1134.573
# MLP_64_32 | Epoch 045 | Train MSE: 1387.578 | Val MSE: 1132.460
# MLP_64_32 | Epoch 046 | Train MSE: 1387.287 | Val MSE: 1129.879
# MLP_64_32 | Epoch 047 | Train MSE: 1382.813 | Val MSE: 1127.224
# MLP_64_32 | Epoch 048 | Train MSE: 1381.815 | Val MSE: 1127.261
# MLP_64_32 | Epoch 049 | Train MSE: 1373.980 | Val MSE: 1122.632
# MLP_64_32 | Epoch 050 | Train MSE: 1377.408 | Val MSE: 1124.872
#
# ==============================
# Training: MLP_128_64
# ==============================
# MLP_128_64 | Epoch 001 | Train MSE: 16722.436 | Val MSE: 4266.153
# MLP_128_64 | Epoch 002 | Train MSE: 2957.742 | Val MSE: 2080.176
# MLP_128_64 | Epoch 003 | Train MSE: 1892.579 | Val MSE: 1646.932
# MLP_128_64 | Epoch 004 | Train MSE: 1688.383 | Val MSE: 1554.080
# MLP_128_64 | Epoch 005 | Train MSE: 1624.488 | Val MSE: 1496.103
# MLP_128_64 | Epoch 006 | Train MSE: 1578.208 | Val MSE: 1449.438
# MLP_128_64 | Epoch 007 | Train MSE: 1540.533 | Val MSE: 1410.460
# MLP_128_64 | Epoch 008 | Train MSE: 1506.360 | Val MSE: 1378.342
# MLP_128_64 | Epoch 009 | Train MSE: 1483.036 | Val MSE: 1351.077
# MLP_128_64 | Epoch 010 | Train MSE: 1462.374 | Val MSE: 1325.142
# MLP_128_64 | Epoch 011 | Train MSE: 1442.466 | Val MSE: 1301.681
# MLP_128_64 | Epoch 012 | Train MSE: 1422.242 | Val MSE: 1278.160
# MLP_128_64 | Epoch 013 | Train MSE: 1397.233 | Val MSE: 1253.970
# MLP_128_64 | Epoch 014 | Train MSE: 1379.408 | Val MSE: 1231.869
# MLP_128_64 | Epoch 015 | Train MSE: 1361.897 | Val MSE: 1210.204
# MLP_128_64 | Epoch 016 | Train MSE: 1348.251 | Val MSE: 1193.331
# MLP_128_64 | Epoch 017 | Train MSE: 1337.670 | Val MSE: 1178.186
# MLP_128_64 | Epoch 018 | Train MSE: 1323.304 | Val MSE: 1165.221
# MLP_128_64 | Epoch 019 | Train MSE: 1316.285 | Val MSE: 1154.779
# MLP_128_64 | Epoch 020 | Train MSE: 1303.636 | Val MSE: 1148.354
# MLP_128_64 | Epoch 021 | Train MSE: 1296.298 | Val MSE: 1136.783
# MLP_128_64 | Epoch 022 | Train MSE: 1290.137 | Val MSE: 1130.017
# MLP_128_64 | Epoch 023 | Train MSE: 1286.810 | Val MSE: 1120.295
# MLP_128_64 | Epoch 024 | Train MSE: 1276.746 | Val MSE: 1118.383
# MLP_128_64 | Epoch 025 | Train MSE: 1270.957 | Val MSE: 1106.935
# MLP_128_64 | Epoch 026 | Train MSE: 1267.601 | Val MSE: 1101.357
# MLP_128_64 | Epoch 027 | Train MSE: 1264.400 | Val MSE: 1095.946
# MLP_128_64 | Epoch 028 | Train MSE: 1255.977 | Val MSE: 1088.709
# MLP_128_64 | Epoch 029 | Train MSE: 1254.249 | Val MSE: 1083.106
# MLP_128_64 | Epoch 030 | Train MSE: 1252.037 | Val MSE: 1077.477
# MLP_128_64 | Epoch 031 | Train MSE: 1240.814 | Val MSE: 1073.101
# MLP_128_64 | Epoch 032 | Train MSE: 1238.828 | Val MSE: 1067.176
# MLP_128_64 | Epoch 033 | Train MSE: 1236.743 | Val MSE: 1063.400
# MLP_128_64 | Epoch 034 | Train MSE: 1231.080 | Val MSE: 1060.150
# MLP_128_64 | Epoch 035 | Train MSE: 1228.996 | Val MSE: 1054.950
# MLP_128_64 | Epoch 036 | Train MSE: 1226.590 | Val MSE: 1050.905
# MLP_128_64 | Epoch 037 | Train MSE: 1223.105 | Val MSE: 1047.877
# MLP_128_64 | Epoch 038 | Train MSE: 1221.375 | Val MSE: 1041.497
# MLP_128_64 | Epoch 039 | Train MSE: 1216.624 | Val MSE: 1039.963
# MLP_128_64 | Epoch 040 | Train MSE: 1211.198 | Val MSE: 1035.149
# MLP_128_64 | Epoch 041 | Train MSE: 1210.835 | Val MSE: 1031.764
# MLP_128_64 | Epoch 042 | Train MSE: 1203.009 | Val MSE: 1027.253
# MLP_128_64 | Epoch 043 | Train MSE: 1206.148 | Val MSE: 1029.816
# MLP_128_64 | Epoch 044 | Train MSE: 1204.782 | Val MSE: 1021.037
# MLP_128_64 | Epoch 045 | Train MSE: 1203.299 | Val MSE: 1017.230
# MLP_128_64 | Epoch 046 | Train MSE: 1198.805 | Val MSE: 1018.399
# MLP_128_64 | Epoch 047 | Train MSE: 1195.229 | Val MSE: 1012.714
# MLP_128_64 | Epoch 048 | Train MSE: 1190.219 | Val MSE: 1010.989
# MLP_128_64 | Epoch 049 | Train MSE: 1186.483 | Val MSE: 1006.624
# MLP_128_64 | Epoch 050 | Train MSE: 1190.034 | Val MSE: 1003.947
#
# ==============================
# Training: MLP_256_128
# ==============================
# MLP_256_128 | Epoch 001 | Train MSE: 12165.889 | Val MSE: 3013.460
# MLP_256_128 | Epoch 002 | Train MSE: 2250.630 | Val MSE: 1747.537
# MLP_256_128 | Epoch 003 | Train MSE: 1749.009 | Val MSE: 1622.695
# MLP_256_128 | Epoch 004 | Train MSE: 1669.204 | Val MSE: 1544.325
# MLP_256_128 | Epoch 005 | Train MSE: 1590.307 | Val MSE: 1463.145
# MLP_256_128 | Epoch 006 | Train MSE: 1531.008 | Val MSE: 1404.441
# MLP_256_128 | Epoch 007 | Train MSE: 1490.109 | Val MSE: 1368.913
# MLP_256_128 | Epoch 008 | Train MSE: 1465.100 | Val MSE: 1340.000
# MLP_256_128 | Epoch 009 | Train MSE: 1443.945 | Val MSE: 1315.342
# MLP_256_128 | Epoch 010 | Train MSE: 1423.034 | Val MSE: 1294.753
# MLP_256_128 | Epoch 011 | Train MSE: 1406.598 | Val MSE: 1275.900
# MLP_256_128 | Epoch 012 | Train MSE: 1390.337 | Val MSE: 1257.007
# MLP_256_128 | Epoch 013 | Train MSE: 1373.120 | Val MSE: 1235.965
# MLP_256_128 | Epoch 014 | Train MSE: 1357.682 | Val MSE: 1212.876
# MLP_256_128 | Epoch 015 | Train MSE: 1337.897 | Val MSE: 1194.284
# MLP_256_128 | Epoch 016 | Train MSE: 1321.310 | Val MSE: 1168.183
# MLP_256_128 | Epoch 017 | Train MSE: 1304.907 | Val MSE: 1151.159
# MLP_256_128 | Epoch 018 | Train MSE: 1294.124 | Val MSE: 1137.644
# MLP_256_128 | Epoch 019 | Train MSE: 1282.700 | Val MSE: 1120.767
# MLP_256_128 | Epoch 020 | Train MSE: 1270.674 | Val MSE: 1109.744
# MLP_256_128 | Epoch 021 | Train MSE: 1258.224 | Val MSE: 1096.332
# MLP_256_128 | Epoch 022 | Train MSE: 1251.164 | Val MSE: 1090.257
# MLP_256_128 | Epoch 023 | Train MSE: 1245.216 | Val MSE: 1075.800
# MLP_256_128 | Epoch 024 | Train MSE: 1234.797 | Val MSE: 1068.515
# MLP_256_128 | Epoch 025 | Train MSE: 1225.486 | Val MSE: 1056.859
# MLP_256_128 | Epoch 026 | Train MSE: 1219.646 | Val MSE: 1046.362
# MLP_256_128 | Epoch 027 | Train MSE: 1210.747 | Val MSE: 1038.054
# MLP_256_128 | Epoch 028 | Train MSE: 1199.133 | Val MSE: 1025.265
# MLP_256_128 | Epoch 029 | Train MSE: 1191.204 | Val MSE: 1019.442
# MLP_256_128 | Epoch 030 | Train MSE: 1179.260 | Val MSE: 1009.176
# MLP_256_128 | Epoch 031 | Train MSE: 1174.457 | Val MSE: 1001.290
# MLP_256_128 | Epoch 032 | Train MSE: 1167.857 | Val MSE: 991.287
# MLP_256_128 | Epoch 033 | Train MSE: 1160.445 | Val MSE: 985.380
# MLP_256_128 | Epoch 034 | Train MSE: 1151.903 | Val MSE: 983.217
# MLP_256_128 | Epoch 035 | Train MSE: 1148.361 | Val MSE: 974.994
# MLP_256_128 | Epoch 036 | Train MSE: 1143.193 | Val MSE: 967.355
# MLP_256_128 | Epoch 037 | Train MSE: 1136.840 | Val MSE: 963.991
# MLP_256_128 | Epoch 038 | Train MSE: 1132.690 | Val MSE: 957.383
# MLP_256_128 | Epoch 039 | Train MSE: 1128.458 | Val MSE: 956.911
# MLP_256_128 | Epoch 040 | Train MSE: 1118.673 | Val MSE: 947.669
# MLP_256_128 | Epoch 041 | Train MSE: 1116.426 | Val MSE: 949.059
# MLP_256_128 | Epoch 042 | Train MSE: 1111.963 | Val MSE: 941.346
# MLP_256_128 | Epoch 043 | Train MSE: 1106.243 | Val MSE: 938.452
# MLP_256_128 | Epoch 044 | Train MSE: 1102.552 | Val MSE: 932.770
# MLP_256_128 | Epoch 045 | Train MSE: 1094.283 | Val MSE: 929.893
# MLP_256_128 | Epoch 046 | Train MSE: 1094.701 | Val MSE: 922.593
# MLP_256_128 | Epoch 047 | Train MSE: 1090.340 | Val MSE: 929.957
# MLP_256_128 | Epoch 048 | Train MSE: 1083.471 | Val MSE: 914.116
# MLP_256_128 | Epoch 049 | Train MSE: 1084.352 | Val MSE: 911.546
# MLP_256_128 | Epoch 050 | Train MSE: 1077.988 | Val MSE: 911.317
#
# ==============================
# Training: MLP_256_128_64
# ==============================
# MLP_256_128_64 | Epoch 001 | Train MSE: 8729.079 | Val MSE: 1919.281
# MLP_256_128_64 | Epoch 002 | Train MSE: 1903.806 | Val MSE: 1618.122
# MLP_256_128_64 | Epoch 003 | Train MSE: 1769.547 | Val MSE: 1506.786
# MLP_256_128_64 | Epoch 004 | Train MSE: 1671.201 | Val MSE: 1420.861
# MLP_256_128_64 | Epoch 005 | Train MSE: 1614.125 | Val MSE: 1371.717
# MLP_256_128_64 | Epoch 006 | Train MSE: 1571.723 | Val MSE: 1336.366
# MLP_256_128_64 | Epoch 007 | Train MSE: 1542.300 | Val MSE: 1300.475
# MLP_256_128_64 | Epoch 008 | Train MSE: 1514.025 | Val MSE: 1274.624
# MLP_256_128_64 | Epoch 009 | Train MSE: 1492.833 | Val MSE: 1248.444
# MLP_256_128_64 | Epoch 010 | Train MSE: 1465.650 | Val MSE: 1228.571
# MLP_256_128_64 | Epoch 011 | Train MSE: 1441.855 | Val MSE: 1200.302
# MLP_256_128_64 | Epoch 012 | Train MSE: 1426.218 | Val MSE: 1178.367
# MLP_256_128_64 | Epoch 013 | Train MSE: 1406.765 | Val MSE: 1163.406
# MLP_256_128_64 | Epoch 014 | Train MSE: 1383.777 | Val MSE: 1137.558
# MLP_256_128_64 | Epoch 015 | Train MSE: 1370.643 | Val MSE: 1117.664
# MLP_256_128_64 | Epoch 016 | Train MSE: 1350.331 | Val MSE: 1092.448
# MLP_256_128_64 | Epoch 017 | Train MSE: 1329.514 | Val MSE: 1070.951
# MLP_256_128_64 | Epoch 018 | Train MSE: 1313.952 | Val MSE: 1052.250
# MLP_256_128_64 | Epoch 019 | Train MSE: 1298.234 | Val MSE: 1041.437
# MLP_256_128_64 | Epoch 020 | Train MSE: 1286.018 | Val MSE: 1026.361
# MLP_256_128_64 | Epoch 021 | Train MSE: 1266.883 | Val MSE: 1018.154
# MLP_256_128_64 | Epoch 022 | Train MSE: 1258.150 | Val MSE: 1012.705
# MLP_256_128_64 | Epoch 023 | Train MSE: 1251.802 | Val MSE: 991.043
# MLP_256_128_64 | Epoch 024 | Train MSE: 1241.893 | Val MSE: 985.510
# MLP_256_128_64 | Epoch 025 | Train MSE: 1230.347 | Val MSE: 985.570
# MLP_256_128_64 | Epoch 026 | Train MSE: 1219.480 | Val MSE: 975.524
# MLP_256_128_64 | Epoch 027 | Train MSE: 1209.312 | Val MSE: 953.019
# MLP_256_128_64 | Epoch 028 | Train MSE: 1198.335 | Val MSE: 953.195
# MLP_256_128_64 | Epoch 029 | Train MSE: 1191.902 | Val MSE: 949.307
# MLP_256_128_64 | Epoch 030 | Train MSE: 1179.095 | Val MSE: 920.064
# MLP_256_128_64 | Epoch 031 | Train MSE: 1169.574 | Val MSE: 913.367
# MLP_256_128_64 | Epoch 032 | Train MSE: 1160.916 | Val MSE: 921.066
# MLP_256_128_64 | Epoch 033 | Train MSE: 1148.580 | Val MSE: 901.097
# MLP_256_128_64 | Epoch 034 | Train MSE: 1138.782 | Val MSE: 888.263
# MLP_256_128_64 | Epoch 035 | Train MSE: 1143.476 | Val MSE: 888.078
# MLP_256_128_64 | Epoch 036 | Train MSE: 1132.138 | Val MSE: 893.248
# MLP_256_128_64 | Epoch 037 | Train MSE: 1124.066 | Val MSE: 876.551
# MLP_256_128_64 | Epoch 038 | Train MSE: 1122.368 | Val MSE: 868.785
# MLP_256_128_64 | Epoch 039 | Train MSE: 1111.353 | Val MSE: 881.614
# MLP_256_128_64 | Epoch 040 | Train MSE: 1108.755 | Val MSE: 858.768
# MLP_256_128_64 | Epoch 041 | Train MSE: 1105.952 | Val MSE: 857.701
# MLP_256_128_64 | Epoch 042 | Train MSE: 1100.195 | Val MSE: 839.158
# MLP_256_128_64 | Epoch 043 | Train MSE: 1089.515 | Val MSE: 839.377
# MLP_256_128_64 | Epoch 044 | Train MSE: 1082.644 | Val MSE: 845.506
# MLP_256_128_64 | Epoch 045 | Train MSE: 1085.342 | Val MSE: 830.974
# MLP_256_128_64 | Epoch 046 | Train MSE: 1078.425 | Val MSE: 830.385
# MLP_256_128_64 | Epoch 047 | Train MSE: 1078.494 | Val MSE: 828.782
# MLP_256_128_64 | Epoch 048 | Train MSE: 1068.411 | Val MSE: 818.846
# MLP_256_128_64 | Epoch 049 | Train MSE: 1063.314 | Val MSE: 835.295
# MLP_256_128_64 | Epoch 050 | Train MSE: 1061.999 | Val MSE: 821.963
#          Model    Architecture   Hidden Layers  Dropout     LR  Weight Decay  \
# 0  PyTorch MLP  MLP_256_128_64  [256, 128, 64]     0.15  0.001        0.0001
# 1  PyTorch MLP       MLP_64_32        [64, 32]     0.10  0.001        0.0001
# 2  PyTorch MLP     MLP_256_128      [256, 128]     0.15  0.001        0.0001
# 3  PyTorch MLP      MLP_128_64       [128, 64]     0.10  0.001        0.0001
#
#    Best Val MSE        R2        MAE       RMSE
# 0    818.845848  0.823547  26.535246  40.199952
# 1   1122.632385  0.807958  27.766630  41.938212
# 2    911.317223  0.797094  29.095167  43.108112
# 3   1003.946976  0.795893  28.666134  43.235503

# %% [markdown]
# ## Final Model Selection
#
# All evaluated models were compared using R², MAE and RMSE on the node-disjoint test set.
#
# LightGBM achieved the best overall performance, obtaining the highest coefficient of determination (R²) and the lowest prediction errors. Consequently, LightGBM was selected as the final model for RTT prediction.
#
# The following sections present the final model performance, feature importance analysis and a direct comparison against the remaining machine learning approaches.

# %%
# -----------------------------
# Final LightGBM Model
# -----------------------------
final_lgbm = LGBMRegressor(
    n_estimators=500,
    num_leaves=127,
    learning_rate=0.05,
    max_depth=-1,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    n_jobs=-1,
    verbose=-1
)

final_lgbm.fit(X_train, y_train)

final_pred = final_lgbm.predict(X_test)

final_mae = mean_absolute_error(y_test, final_pred)
final_rmse = np.sqrt(mean_squared_error(y_test, final_pred))
final_r2 = r2_score(y_test, final_pred)

print("FINAL LIGHTGBM PERFORMANCE")
print("--------------------------")
print(f"MAE  : {final_mae:.3f} ms")
print(f"RMSE : {final_rmse:.3f} ms")
print(f"R²   : {final_r2:.4f}")

final_results_df = pd.DataFrame([{
    "Final Model": "LightGBM",
    "n_estimators": 500,
    "num_leaves": 127,
    "learning_rate": 0.05,
    "R2": final_r2,
    "MAE": final_mae,
    "RMSE": final_rmse
}])

display(final_results_df)
# Out:
# FINAL LIGHTGBM PERFORMANCE
# --------------------------
# MAE  : 24.628 ms
# RMSE : 36.957 ms
# R²   : 0.8509
#   Final Model  n_estimators  num_leaves  learning_rate        R2        MAE  \
# 0    LightGBM           500         127           0.05  0.850872  24.627622
#
#         RMSE
# 0  36.956518

# %% [markdown]
# ## Feature Importance Discussion
#
# The feature importance analysis shows that RTT prediction is mainly influenced by distance and network-related information.
#
# Features such as distance, ASN, provider and IP prefixes help the model understand how data travels through the network and how different routing paths affect latency.
#
# The results suggest that RTT depends not only on geographic distance, but also on the characteristics of the networks involved.

# %%
# -----------------------------
# Final LightGBM Feature Importance
# -----------------------------
lgbm_importance_df = pd.DataFrame({
    "Feature": features,
    "Importance": final_lgbm.feature_importances_
}).sort_values(by="Importance", ascending=False)

display(lgbm_importance_df)

plt.figure(figsize=(12, 6))
plt.bar(lgbm_importance_df["Feature"], lgbm_importance_df["Importance"])
plt.title("Final LightGBM Feature Importance")
plt.xlabel("Feature")
plt.ylabel("Importance")
plt.xticks(rotation=45, ha="right")
plt.show()
# Out:
#           Feature  Importance
# 0     distance_km        8937
# 6     src_country        5849
# 7     dst_country        5514
# 10  src_prefix_16        5186
# 11  dst_prefix_16        5033
# 2         src_asn        4815
# 3         dst_asn        4591
# 5   dst_continent        4232
# 4   src_continent        4228
# 8    src_provider        4175
# 9    dst_provider        4128
# 1       hop_count        3729
# 12  src_conn_type        1327
# 13  dst_conn_type        1256

# %% [markdown]
# ## Conclusion
#
# Several machine learning approaches were evaluated for RTT prediction using network metadata.
#
# Among all tested models, LightGBM achieved the best predictive performance and was therefore selected as the final model. The results demonstrate that gradient-boosted tree methods are particularly effective for structured networking datasets, outperforming both Random Forest and neural-network approaches.
#
# Feature importance analysis further showed that distance, routing characteristics and network-provider information are the dominant factors influencing RTT. The node-disjoint evaluation protocol confirms that the model generalizes to previously unseen network endpoints rather than memorizing known paths.

# %%
model_comparison_df = pd.DataFrame([
    {
        "Model": "Random Forest",
        "Best R2": rf_results_df.iloc[0]["R2"],
        "Best MAE": rf_results_df.iloc[0]["MAE"],
        "Best RMSE": rf_results_df.iloc[0]["RMSE"]
    },
    {
        "Model": "XGBoost",
        "Best R2": xgb_results_df.iloc[0]["R2"],
        "Best MAE": xgb_results_df.iloc[0]["MAE"],
        "Best RMSE": xgb_results_df.iloc[0]["RMSE"]
    },
    {
        "Model": "LightGBM",
        "Best R2": lgbm_results_df.iloc[0]["R2"],
        "Best MAE": lgbm_results_df.iloc[0]["MAE"],
        "Best RMSE": lgbm_results_df.iloc[0]["RMSE"]
    },
    {
        "Model": "PyTorch MLP",
        "Best R2": torch_mlp_results_df.iloc[0]["R2"],
        "Best MAE": torch_mlp_results_df.iloc[0]["MAE"],
        "Best RMSE": torch_mlp_results_df.iloc[0]["RMSE"]
    }
])

model_comparison_df = model_comparison_df.sort_values(
    by="Best R2",
    ascending=False
).reset_index(drop=True)

display(model_comparison_df)
# Out:
#            Model   Best R2   Best MAE  Best RMSE
# 0       LightGBM  0.850872  24.627622  36.956518
# 1        XGBoost  0.846776  25.020077  37.460610
# 2  Random Forest  0.829154  24.975415  39.556093
# 3    PyTorch MLP  0.823547  26.535246  40.199952
